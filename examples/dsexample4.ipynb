# %% [markdown]
# #4th-order quadrature example
#
# Ported from the MATLAB file `dsexample4.m`, written by R. Schreier.

# %% [markdown]
# Preliminary code to set-up IPython:

# %%
from __future__ import division
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the `deltasigma` module.

# %%
import deltasigma as ds

# %%
fig_number = 0
base_name = 'dsexample4'
def save_fig(fig_number):
    save_name = f'{base_name}_fig{fig_number:02d}.pdf'
    fig_number = fig_number + 1
    plt.gcf().savefig(save_name)
    return fig_number

# %% [markdown]
# ## ADC specifications
#
# Specify the parameters of the the ADC design:

# %%
order = 4
osr = 32
M = 8
NG = -50
ING = -10
f0 = 1 / 16
quadrature = True
form = 'PFB'
nlev = M + 1
z0 = np.exp(1j*2*np.pi*f0)
bw = 1./osr
delta = 2
FullScale = M

# %% [markdown]
# ADC specifications up to now:

# %%
adc = {}
adc['order'] = order
adc['osr'] = osr
adc['M'] = M
adc['f0'] = f0
adc['quadrature'] = quadrature
adc['form'] = form

# %% [markdown]
# ## Choosing the NTF and realization...

# %%
ntf0 = ds.synthesizeQNTF(order, osr, f0, NG, ING)
print('ntf0 = \n')
print(ds.pretty_lti(ntf0))
# Out:
# ntf0 =
#
#   (z - 0.888 - 0.4598j) (z - 0.9239 + 0.3827j) (z - 0.9239 - 0.3827j) (z - 0.953 - 0.3028j)
# ---------------------------------------------------------------------------------------------
#  (z - 0.5739 - 0.5699j) (z - 0.5913 - 0.2449j) (z - 0.6731 + 0.2788j) (z - 0.8088 - 0.0028j)

# %%
ABCD = ds.realizeQNTF(ntf0, form, quadrature)
adc['ABCD'] = ABCD.copy()
print('ABCD matrix: \n')
print(ABCD)
# Out:
# ABCD matrix:
#
# [[ 0.8880372 +4.59771611e-01j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.05160829+0.00000000e+00j  0.05160829-3.62552581e-18j]
#  [ 0.60725927+7.94503732e-01j  0.95304475+3.02829501e-01j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.32296443-3.43216492e-17j]
#  [ 0.        +0.00000000e+00j  0.94589279+3.24479322e-01j
#    0.92387953+3.82683432e-01j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.91615063-6.44605920e-17j]
#  [ 0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.92387953-3.82683432e-01j
#    0.        +0.00000000e+00j  0.17778533-3.25078876e-17j]
#  [ 0.        -0.00000000e+00j  0.        -0.00000000e+00j
#   -0.99349829-1.13847053e-01j -0.74054592-6.72005754e-01j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j]]

# %% [markdown]
# ## Calculate the STF
#
# This also recalculates the NTF, which is the same as before.

# %%
ntf, stf = ds.calculateTF(ABCD)
print('ntf = \n')
print(ds.pretty_lti(ntf))
print('\n\nstf = \n')
print(ds.pretty_lti(stf))
# save ADC parameters
adc['ntf'] = ntf
adc['stf'] = stf
# Out:
# ntf =
#
#   (z - 0.888 - 0.4598j) (z - 0.9239 + 0.3827j) (z - 0.9239 - 0.3827j) (z - 0.953 - 0.3028j)
# ---------------------------------------------------------------------------------------------
#  (z - 0.5739 - 0.5699j) (z - 0.5913 - 0.2449j) (z - 0.6731 + 0.2788j) (z - 0.8088 - 0.0028j)
#
#
# stf =
#
#                                                         (z - 0.9239 + 0.3827j)
# (-0.0107 - 0.0505j) ---------------------------------------------------------------------------------------------
#                      (z - 0.5739 - 0.5699j) (z - 0.5913 - 0.2449j) (z - 0.6731 + 0.2788j) (z - 0.8088 - 0.0028j)
# C:\Users\hansp\miniconda3\envs\HTU25\Lib\site-packages\scipy\signal\_filter_design.py:1230: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   b, a = normalize(b, a)

# %%
plt.figure(figsize=(12,8))
ds.DocumentNTF(ABCD, osr=32, f0=1./16, quadrature=True);
fig_number = save_fig(fig_number)

# %% [markdown]
# ## Time-domain simulations

# %%
#setup the figure
plt.figure(figsize=(13, 5))
plt.subplot2grid((1, 3), (0, 0), colspan=2)
# spectrum
ds.PlotExampleSpectrum(ntf, M, osr, f0, quadrature)
plt.title('Example Spectrum')
# SNR simulation
plt.subplot2grid((1, 3), (0, 2))
snr, amp = ds.simulateSNR(ABCD, osr, None, f0, nlev)
plt.plot(amp, snr, 'ob')
ds.figureMagic((-100, 0), 10, 2, (0, 100), 10, 2)
plt.xlabel('Input Level (dBFS)')
plt.ylabel('SQNR (dB)')
peak_snr, peak_amp = ds.peakSNR(snr, amp)
adc['peak_snr'] = peak_snr
msg = 'peak SQNR = %4.1fdB  \n@ amp=%4.1fdB  ' % (peak_snr, peak_amp)
plt.text(peak_amp - 10, peak_snr, msg, ha='right', va='center')
msg = 'OSR=%d ' % osr
plt.text(0, 5, msg, ha='right')
plt.title('SQNR Plot')
plt.tight_layout()
fig_number = save_fig(fig_number)
# Out:
# C:\Users\hansp\Desktop\42\SVN\python-deltasigma\deltasigma\_simulateDSM.py:216: UserWarning: Using a slow implementation of simulateDSM
# Refer to the docs for how to switch to a fast one
#   warn('Using a slow implementation of simulateDSM\n' +
# C:\Users\hansp\Desktop\42\SVN\python-deltasigma\deltasigma\_simulateDSM_python.py:113: UserWarning: Multiple input delta sigma structures have had little testing.
#   warn("Multiple input delta sigma structures have had little testing.")
# C:\Users\hansp\Desktop\42\SVN\python-deltasigma\deltasigma\_figureMagic.py:112: UserWarning: figureMagic() got xLab=2, but xLab is not implemented and will be ignored.
#   warn(('figureMagic() got xLab=%s, but xLab is not implemented and ' +
# C:\Users\hansp\Desktop\42\SVN\python-deltasigma\deltasigma\_figureMagic.py:115: UserWarning: figureMagic() got yLab=2, but xLab is not implemented and will be ignored.
#   warn(('figureMagic() got yLab=%s, but xLab is not implemented and ' +
# C:\Users\hansp\AppData\Local\Temp\ipykernel_15464\1121472603.py:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   msg = 'peak SQNR = %4.1fdB  \n@ amp=%4.1fdB  ' % (peak_snr, peak_amp)

# %% [markdown]
# ## ADC parameters

# %%
for k in adc:
    print('%s:' % k)
    print('\t'+str(adc[k]))
# Out:
# order:
# 	4
# osr:
# 	32
# M:
# 	8
# f0:
# 	0.0625
# quadrature:
# 	True
# form:
# 	PFB
# ABCD:
# 	[[ 0.8880372 +4.59771611e-01j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.05160829+0.00000000e+00j  0.05160829-3.62552581e-18j]
#  [ 0.60725927+7.94503732e-01j  0.95304475+3.02829501e-01j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.32296443-3.43216492e-17j]
#  [ 0.        +0.00000000e+00j  0.94589279+3.24479322e-01j
#    0.92387953+3.82683432e-01j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.91615063-6.44605920e-17j]
#  [ 0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.        +0.00000000e+00j  0.92387953-3.82683432e-01j
#    0.        +0.00000000e+00j  0.17778533-3.25078876e-17j]
#  [ 0.        -0.00000000e+00j  0.        -0.00000000e+00j
#   -0.99349829-1.13847053e-01j -0.74054592-6.72005754e-01j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j]]
# ntf:
# 	(array([0.8880372 +0.45977161j, 0.92387953+0.38268343j,
#        0.92387953-0.38268343j, 0.95304475+0.3028295j ]), array([0.57387778+0.5699217j , 0.5912503 +0.24490389j,
#        0.67307228-0.27879567j, 0.80878837+0.00279738j]), np.complex128(1+0j))
# stf:
# 	(array([0.92387953-0.38268343j]), array([0.57387778+0.5699217j , 0.5912503 +0.24490389j,
#        0.67307228-0.27879567j, 0.80878837+0.00279738j]), np.complex128(-0.010659853046530277-0.05049538236537687j))
# peak_snr:
# 	[[84.61240252]]

# %% [markdown]
# ## Effect of example I/Q mismatch

# %%
from scipy.signal import freqz
nd = ds._utils._get_num_den
plt.figure(figsize=(12, 5))
ABCDr = ds.mapQtoR(ABCD)
ABCDr[1, -1] = 1.01 * ABCDr[1, -1]
H, G, HI, GI = ds.calculateQTF(ABCDr)
f = ds.ds_freq(osr, f0, quadrature)
w = 2 * np.pi * f
NTF = freqz(*nd(H), worN=w)[1]
INTF = freqz(*nd(HI), worN=w)[1]
STF = freqz(*nd(G), worN=w)[1]
ISTF = freqz(*nd(GI), worN=w)[1]
plt.plot(f, ds.dbv(NTF), 'b', lw=2, label='NTF')
plt.plot(f, ds.dbv(INTF), 'c', lw=2, label='INTF')
plt.plot(f, ds.dbv(STF), 'm', lw=2, label='STF')
plt.plot(f, ds.dbv(ISTF), 'r', lw=2, label='ISTF')
inband = (np.logical_and(f >= f0 - 0.5/osr, f <= f0 + 0.5/osr))
# NG LEVEL
ng = ds.dbp(np.mean(np.abs(NTF[inband])**2))
plt.plot(f0 + 0.5*np.array((-1, 1))/osr, ng*np.array((1, 1)), 'k', lw=3)
msg = '  NG = %.0fdB ' % ng
plt.text(f0 + 0.5/osr, ng, msg, ha='left', va='center')
# ING LEVEL
ing = ds.dbp(np.mean(np.abs(INTF[inband])**2))
plt.plot([f0 - 0.5/osr, f0 +0.5/osr], [ing, ing], 'k', lw=3)
msg = '  ING = %.0fdB ' % ing
plt.text(f0 + 0.5/osr, ing, msg, ha='left', va='center')
# IRR LEVEL
irr = np.min(ds.dbv(STF[inband]) - ds.dbv(ISTF[inband]))
plt.plot([f0 - 0.5/osr, f0 + 0.5/osr], [-irr, -irr], 'k', lw=3)
msg = '  IRR = %.0fdB ' % irr
plt.text(f0 + 0.5/osr, -irr, msg, ha='left', va='center')
ds.figureMagic((-0.5, 0.5), 2./16, 2, (-80, 15), 20, 2, None, 'Example I/Q Mismatch')
plt.xlabel('frequency')
plt.legend(loc=3);
fig_number = save_fig(fig_number)
# Out:
# C:\Users\hansp\miniconda3\envs\HTU25\Lib\site-packages\scipy\signal\_filter_design.py:1230: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   b, a = normalize(b, a)
# C:\Users\hansp\Desktop\42\SVN\python-deltasigma\deltasigma\_figureMagic.py:112: UserWarning: figureMagic() got xLab=2, but xLab is not implemented and will be ignored.
#   warn(('figureMagic() got xLab=%s, but xLab is not implemented and ' +
# C:\Users\hansp\Desktop\42\SVN\python-deltasigma\deltasigma\_figureMagic.py:115: UserWarning: figureMagic() got yLab=2, but xLab is not implemented and will be ignored.
#   warn(('figureMagic() got yLab=%s, but xLab is not implemented and ' +

# %% [markdown]
# ##Further information about NTF synthesis
#
# Please refer to `help(synthesizeNTF)` for detailed - and possibly more updated - documentation!
#
# `help(synthesizeNTF)` as of writing:
#
# **synthesizeQNTF**(order=4, OSR=64, f0=0.0, NG=-60, ING=-20, n_im=None)**
#
# Synthesize a noise transfer function for a quadrature modulator.
#
# **Parameters:**
#
# order : *int, optional*
#     The order of the modulator. Defaults to 4.
#
# OSR : *int, optional*
#     The oversampling ratio. Defaults to 64.
#
# f0 : *float, optional*
#     The center frequency, normalized such that $1 \rightarrow f_s$.
#     Defaults to 0, ie to a low-pass modulator.
#
# NG : *float, optional*
#     The in-band noise gain, expressed in dB. Defaults to -60.
#
# ING : *float, optional*
#     The image-band noise gain, in dB. Defaults to -20.
#
# n_im : *int, optional*
#     The number of in-band image zeros, defaults to `floor(order/3)`.
#
# **Returns:**
#
# ntf : *(z, p, k) tuple*
#     `ntf` is a zpk tuple containing the zeros, poles and the gain of the
#     synthesized NTF.
#
# .. note::
#
#     From the Matlab Delta-Sigma Toobox:
#     ALPHA VERSION:
#     This function uses an experimental ad-hoc method that is
#     neither optimal nor robust.
#
# **Example:**
#
# Fourth order quadrature modulator::
#
#     from deltasigma import *
#     order = 4
#     osr = 32
#     NG = -50
#     ING = -10
#     f0 = 1 / 16
#     ntf0 = synthesizeQNTF(order, osr, f0, NG, ING)
#     pretty_lti(ntf0)
#
# **Returns:**
#
# ```
#       (z - 0.888 - 0.4598j) (z - 0.9239 + 0.3827j) (z - 0.9239 - 0.3827j) (z - 0.953 - 0.3028j)
#       ---------------------------------------------------------------------------------------------
#        (z - 0.5739 - 0.5699j) (z - 0.5913 - 0.2449j) (z - 0.6731 + 0.2788j) (z - 0.8088 - 0.0028j)
#
# ```
